# %%
import pandas as pd

df = pd.read_csv("restaurant_db_data_dictionary.csv")

print(df.head())
print(df.info())
print(df.describe())
# Out:
#            Table             Field  \
# 0     menu_items      menu_item_id
# 1     menu_items         item_name
# 2     menu_items          category
# 3     menu_items             price
# 4  order_details  order_details_id
#
#                                     Description
# 0                      Unique ID of a menu item
# 1                           Name of a menu item
# 2  Category or type of cuisine of the menu item
# 3         Price of the menu item (US Dollars $)
# 4              Unique ID of an item in an order
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Table        9 non-null      object
#  1   Field        9 non-null      object
#  2   Description  9 non-null      object
# dtypes: object(3)
# memory usage: 348.0+ bytes
# None
#                 Table         Field               Description
# count               9             9                         9
# unique              2             9                         9
# top     order_details  menu_item_id  Unique ID of a menu item
# freq                5             1                         1

# %%
print(df.columns)
# Out:
# Index(['Table', 'Field', 'Description'], dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for col in df.select_dtypes(include='object').columns:
    df[col] = le.fit_transform(df[col].astype(str))

# %%
from sklearn.ensemble import IsolationForest

iso = IsolationForest(contamination=0.05)

df["outlier"] = iso.fit_predict(df)

clean_df = df[df["outlier"] == 1]

# %%
for col in df.columns:
    print(col)
# Out:
# Table
# Field
# Description
# outlier

# %%
df = df.drop_duplicates()

# %%
df.to_csv("restaurant_cleaned.csv", index=False)
