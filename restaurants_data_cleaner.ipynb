# %%
import pandas as pd

df = pd.read_csv("Data Dictionary_Restaurants Data.csv")

print(df.head())
print(df.info())
print(df.isnull().sum())
# Out:
#             Fields                                       Description
# 0    Restaurant ID    Unique Identification number of the restaurant
# 1  Restaurant Name                            Name of the restaurant
# 2     Country Code  Unique code of the country restaurant is located
# 3             City                   City the restaurant is situated
# 4          Address                         Address of the restaurant
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Fields       21 non-null     object
#  1   Description  21 non-null     object
# dtypes: object(2)
# memory usage: 468.0+ bytes
# None
# Fields         0
# Description    0
# dtype: int64

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.strip()

# %%
df.columns = df.columns.str.strip()

# %%
print(df.columns)
# Out:
# Index(['Fields', 'Description'], dtype='object')

# %%
print(df.head())
print(df.dtypes)
# Out:
#             Fields                                       Description
# 0    Restaurant ID    Unique Identification number of the restaurant
# 1  Restaurant Name                            Name of the restaurant
# 2     Country Code  Unique code of the country restaurant is located
# 3             City                   City the restaurant is situated
# 4          Address                         Address of the restaurant
# Fields         object
# Description    object
# dtype: object

# %%
df.columns = df.columns.str.strip()

# %%
hasattr(rf, "estimators_")
# Out:
# False

# %%
import pandas as pd

df = pd.read_csv("restaurants.csv")

df_clean = df.dropna()   # cleaning step

df_clean.to_csv("restaurants_cleaned.csv", index=False)
