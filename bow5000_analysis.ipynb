# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("bow5000.csv")

# %%
df.head()
df.shape
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 147 entries, 0 to 146
# Columns: 5002 entries, Unnamed: 0 to petyr
# dtypes: int64(5000), object(2)
# memory usage: 5.6+ MB
# Unnamed: 0    0
# category_     0
# the           0
# and           0
# to            0
#              ..
# rowan's       0
# curry         0
# enzian        0
# ellie         0
# petyr         0
# Length: 5002, dtype: int64

# %%
df = df.drop_duplicates()

# %%
df = df.dropna()

# %%
df.columns = df.columns.str.strip().str.lower()

# %%
def remove_outliers_iqr(dataframe, column):
    if column not in dataframe.columns:
        raise ValueError(f"Column '{column}' not found. Available columns: {list(dataframe.columns)}")
    
    Q1 = dataframe[column].quantile(0.25)
    Q3 = dataframe[column].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    return dataframe[(dataframe[column] >= lower) & 
                     (dataframe[column] <= upper)]

# %%
df.describe()
# Out:
#                 the           and            to             a           of  \
# count    147.000000    147.000000    147.000000    147.000000   147.000000
# mean    6986.809524   3629.122449   3041.272109   2990.925170  2647.727891
# std     4465.435505   2386.352751   1890.689573   1784.245599  1818.402270
# min      491.000000    304.000000    208.000000    301.000000   202.000000
# 25%     4113.000000   2094.000000   1814.000000   1865.500000  1488.500000
# 50%     6147.000000   3084.000000   2785.000000   2645.000000  2144.000000
# 75%     8835.000000   4612.500000   3711.000000   3724.000000  3232.000000
# max    25633.000000  15874.000000  12024.000000  11175.000000  9857.000000
#
#                  i           he           in          was           it  ...  \
# count   147.000000   147.000000   147.000000   147.000000   147.000000  ...
# mean   1807.795918  2169.904762  1932.755102  2000.183673  1732.272109  ...
# ...

# %%
df.corr(numeric_only=True)
# Out:
#               the       and        to         a        of         i        he  \
# the      1.000000  0.952482  0.960650  0.962585  0.967478  0.453755  0.865776
# and      0.952482  1.000000  0.931404  0.927536  0.937355  0.495402  0.854450
# to       0.960650  0.931404  1.000000  0.945016  0.944907  0.551864  0.838977
# a        0.962585  0.927536  0.945016  1.000000  0.960087  0.488123  0.858744
# of       0.967478  0.937355  0.944907  0.960087  1.000000  0.449766  0.844282
# ...           ...       ...       ...       ...       ...       ...       ...
# rowan's  0.336772  0.422501  0.391630  0.191036  0.328005  0.301743  0.249078
# curry    0.351819  0.437090  0.404487  0.206455  0.339333  0.319993  0.258411
# enzian   0.231220  0.144448  0.207433  0.239419  0.304118 -0.027102  0.055767
# ellie    0.170853  0.218329  0.189892  0.131372  0.168377  0.163253  0.185286
# petyr    0.346762  0.426114  0.394543  0.209166  0.328505  0.314356  0.260118
#
# ...

# %%
df.to_csv("bow5000_cleaned.csv", index=False)
